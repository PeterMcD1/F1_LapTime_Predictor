# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from dateutil.parser import parse
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split, TensorDataset
import matplotlib.pyplot as plt

# %%
###TODO: expand to full data, figure out how to visualize the difference in compounds or just train multiple neural networks on each compound, fix the size error idk why thats happening

# %%
filenames = ["LapWeather_Australian Grand Prix.csv","LapWeather_Austrian Grand Prix.csv","LapWeather_Azerbaijan Grand Prix.csv","LapWeather_Bahrain Grand Prix.csv","LapWeather_Belgian Grand Prix.csv","LapWeather_Brazilian Grand Prix.csv","LapWeather_British Grand Prix.csv","LapWeather_Canadian Grand Prix.csv", "LapWeather_Chinese Grand Prix.csv","LapWeather_French Grand Prix.csv","LapWeather_German Grand Prix.csv","LapWeather_Hungarian Grand Prix.csv","LapWeather_Italian Grand Prix.csv","LapWeather_Japanese Grand Prix.csv","LapWeather_Mexican Grand Prix.csv","LapWeather_Monaco Grand Prix.csv","LapWeather_Russian Grand Prix.csv","LapWeather_Singapore Grand Prix.csv","LapWeather_Spanish Grand Prix.csv","LapWeather_United States Grand Prix.csv"]
combined_csv = pd.concat([pd.read_csv(f) for f in filenames ])
print(combined_csv)
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
# Out:
#      Unnamed: 0                    Time  DriverNumber                 LapTime  \
# 0             0  0 days 00:08:44.363000             5                     NaN
# 1             1  0 days 00:10:14.925000             5  0 days 00:01:30.562000
# 2             2  0 days 00:11:45.102000             5  0 days 00:01:30.177000
# 3             3  0 days 00:13:14.712000             5  0 days 00:01:29.610000
# 4             4  0 days 00:14:44.252000             5  0 days 00:01:29.540000
# ..          ...                     ...           ...                     ...
# 926         926  0 days 02:02:52.173000            20  0 days 00:01:40.578000
# 927         927  0 days 02:04:32.739000            20  0 days 00:01:40.566000
# 928         928  0 days 02:06:13.291000            20  0 days 00:01:40.552000
# 929         929  0 days 02:07:54.121000            20  0 days 00:01:40.830000
# 930         930  0 days 02:09:37.534000            20  0 days 00:01:43.413000
#
#      LapNumber              PitOutTime PitInTime             Sector1Time  \
# 0            1  0 days 00:00:04.103000       NaN                     NaN
# 1            2                     NaN       NaN  0 days 00:00:30.174000
# 2            3                     NaN       NaN  0 days 00:00:30.157000
# 3            4                     NaN       NaN  0 days 00:00:29.954000
# 4            5                     NaN       NaN  0 days 00:00:29.827000
# ..         ...                     ...       ...                     ...
# 926         52                     NaN       NaN  0 days 00:00:26.425000
# 927         53                     NaN       NaN  0 days 00:00:26.656000
# 928         54                     NaN       NaN  0 days 00:00:26.604000
# 929         55                     NaN       NaN  0 days 00:00:26.794000
# 930         56                     NaN       NaN  0 days 00:00:26.971000
#
#                 Sector2Time             Sector3Time  ... IsAccurate AirTemp  \
# 0    0 days 00:00:24.142000  0 days 00:00:36.352000  ...      False    24.2
# 1    0 days 00:00:23.995000  0 days 00:00:36.393000  ...       True    24.2
# 2    0 days 00:00:23.966000  0 days 00:00:36.054000  ...       True    23.9
# 3    0 days 00:00:23.871000  0 days 00:00:35.785000  ...       True    23.9
# 4    0 days 00:00:23.850000  0 days 00:00:35.863000  ...       True    23.5
# ..                      ...                     ...  ...        ...     ...
# 926  0 days 00:00:39.789000  0 days 00:00:34.364000  ...       True    23.3
# 927  0 days 00:00:40.235000  0 days 00:00:33.675000  ...       True    23.4
# 928  0 days 00:00:40.026000  0 days 00:00:33.922000  ...       True    23.4
# 929  0 days 00:00:40.059000  0 days 00:00:33.977000  ...       True    23.2
# 930  0 days 00:00:40.825000  0 days 00:00:35.617000  ...       True    23.1
#
#     Humidity  Pressure  Rainfall  TrackTemp  WindDirection  WindSpeed Track  \
# 0       36.3     997.0     False       38.9            307        4.1     1
# 1       36.3     996.9     False       38.2            296        3.8     1
# 2       36.5     997.1     False       36.7            289        4.3     1
# 3       36.3     997.1     False       36.8            255        2.9     1
# 4       36.3     997.2     False       36.4            267        2.5     1
# ..       ...       ...       ...        ...            ...        ...   ...
# 926     33.4    1005.0     False       32.3            206        1.5    20
# 927     33.7    1005.1     False       32.3            255        0.9    20
# 928     34.0    1004.9     False       32.3            149        1.4    20
# 929     34.9    1004.9     False       32.2            118        1.8    20
# 930     35.0    1004.8     False       32.0             87        1.6    20
#
#      LapStartDate
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 926       41:11.7
# 927       42:52.2
# 928       44:32.8
# 929       46:13.4
# 930       47:54.2
#
# [21359 rows x 36 columns]

# %%
df = pd.read_csv('combined_csv.csv')
df = df[df["IsAccurate"]==True]
print(len(df))
df = df[df["TrackStatus"]==1]
print(df)
df = df.drop(['Time','DriverNumber','WindDirection','LapStartDate', 'Unnamed: 0', 'PitOutTime', 'PitInTime', 'Sector1Time','Sector2Time','Sector3Time','Sector1SessionTime','Sector2SessionTime','Sector3SessionTime','SpeedI1','SpeedI2','SpeedST','IsPersonalBest','FreshTyre','SpeedFL','LapStartTime','Driver','TrackStatus','IsAccurate'], axis=1)
df = df.dropna()
dfOutput = df['LapTime']
train_targets = dfOutput.to_numpy()

for i in range(len(train_targets)):
    train_targets[i] = train_targets[i].replace('0 days ', '')
# print(train_targets)
actual_train_targets = []
for time in train_targets:
    td = parse(time) - parse('00:00:00')
    seconds = td.total_seconds()
    actual_train_targets.append(seconds)
# print(actual_train_targets)
dfLapTime = pd.DataFrame(actual_train_targets)

df['LapTime'] = dfLapTime
df = df.dropna()
cols = ['LapTime']
Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3-Q1
df = df[(~(df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]
dfInput = df.drop(['LapTime'], axis=1)
dfInput = dfInput.replace({'SUPERHARD':1, 'HARD':2, 'MEDIUM':3, 'SOFT':4,'SUPERSOFT': 5, 'ULTRASOFT': 6,'HYPERSOFT':7,"INTERMEDIATE":0,"WET":-1})
dfInput = dfInput.replace({'Ferrari':1,'Mercedes':2,'Red Bull Racing':3, 'McLaren':4, 'Renault':5, 'Force India':6, 'Sauber':7, 'Williams':8, 'Toro Rosso':9, 'Haas F1 Team':10, 'Racing Point':6})
train_inputs = dfInput.to_numpy()
inputs_array = train_inputs.astype('float64')
dfOutput = df['LapTime']
targets_array = dfOutput.to_numpy()
inputs = torch.Tensor(inputs_array)
targets = torch.Tensor(targets_array)

new_shape = (len(targets_array), 1)
targets = targets.view(new_shape)
print(targets.shape)

print(inputs_array)
print(targets_array)
# Out:
# 18288
#        Unnamed: 0                    Time  DriverNumber  \
# 1               1  0 days 00:10:14.925000             5
# 2               2  0 days 00:11:45.102000             5
# 3               3  0 days 00:13:14.712000             5
# 4               4  0 days 00:14:44.252000             5
# 7               7  0 days 00:19:14.407000             5
# ...           ...                     ...           ...
# 21354         926  0 days 02:02:52.173000            20
# 21355         927  0 days 02:04:32.739000            20
# 21356         928  0 days 02:06:13.291000            20
# 21357         929  0 days 02:07:54.121000            20
# 21358         930  0 days 02:09:37.534000            20
#
#                       LapTime  LapNumber PitOutTime PitInTime  \
# 1      0 days 00:01:30.562000          2        NaN       NaN
# 2      0 days 00:01:30.177000          3        NaN       NaN
# 3      0 days 00:01:29.610000          4        NaN       NaN
# 4      0 days 00:01:29.540000          5        NaN       NaN
# 7      0 days 00:01:29.481000          8        NaN       NaN
# ...                       ...        ...        ...       ...
# 21354  0 days 00:01:40.578000         52        NaN       NaN
# 21355  0 days 00:01:40.566000         53        NaN       NaN
# 21356  0 days 00:01:40.552000         54        NaN       NaN
# 21357  0 days 00:01:40.830000         55        NaN       NaN
# 21358  0 days 00:01:43.413000         56        NaN       NaN
#
#                   Sector1Time             Sector2Time             Sector3Time  \
# 1      0 days 00:00:30.174000  0 days 00:00:23.995000  0 days 00:00:36.393000
# 2      0 days 00:00:30.157000  0 days 00:00:23.966000  0 days 00:00:36.054000
# 3      0 days 00:00:29.954000  0 days 00:00:23.871000  0 days 00:00:35.785000
# 4      0 days 00:00:29.827000  0 days 00:00:23.850000  0 days 00:00:35.863000
# 7      0 days 00:00:29.827000  0 days 00:00:23.867000  0 days 00:00:35.787000
# ...                       ...                     ...                     ...
# 21354  0 days 00:00:26.425000  0 days 00:00:39.789000  0 days 00:00:34.364000
# 21355  0 days 00:00:26.656000  0 days 00:00:40.235000  0 days 00:00:33.675000
# 21356  0 days 00:00:26.604000  0 days 00:00:40.026000  0 days 00:00:33.922000
# 21357  0 days 00:00:26.794000  0 days 00:00:40.059000  0 days 00:00:33.977000
# 21358  0 days 00:00:26.971000  0 days 00:00:40.825000  0 days 00:00:35.617000
#
#        ... IsAccurate AirTemp Humidity  Pressure  Rainfall  TrackTemp  \
# 1      ...       True    24.2     36.3     996.9     False       38.2
# 2      ...       True    23.9     36.5     997.1     False       36.7
# 3      ...       True    23.9     36.3     997.1     False       36.8
# 4      ...       True    23.5     36.3     997.2     False       36.4
# 7      ...       True    23.8     35.6     997.0     False       37.5
# ...    ...        ...     ...      ...       ...       ...        ...
# 21354  ...       True    23.3     33.4    1005.0     False       32.3
# 21355  ...       True    23.4     33.7    1005.1     False       32.3
# 21356  ...       True    23.4     34.0    1004.9     False       32.3
# 21357  ...       True    23.2     34.9    1004.9     False       32.2
# 21358  ...       True    23.1     35.0    1004.8     False       32.0
#
#        WindDirection  WindSpeed Track  LapStartDate
# 1                296        3.8     1           NaN
# 2                289        4.3     1           NaN
# 3                255        2.9     1           NaN
# 4                267        2.5     1           NaN
# 7                297        2.9     1           NaN
# ...              ...        ...   ...           ...
# 21354            206        1.5    20       41:11.7
# 21355            255        0.9    20       42:52.2
# 21356            149        1.4    20       44:32.8
# 21357            118        1.8    20       46:13.4
# 21358             87        1.6    20       47:54.2
#
# [17264 rows x 36 columns]
# torch.Size([13743, 1])
# [[ 2.   6.   4.  ... 38.2  3.8  1. ]
#  [ 3.   6.   5.  ... 36.7  4.3  1. ]
#  [ 4.   6.   6.  ... 36.8  2.9  1. ]
#  ...
#  [65.   6.  52.  ... 34.3  1.4 16. ]
#  [66.   6.  53.  ... 34.1  1.5 16. ]
#  [67.   6.  54.  ... 34.3  1.7 16. ]]
# [ 90.177  89.61   89.54  ... 100.552 100.83  103.413]

# %%
dataset = TensorDataset(inputs, targets)

# %%
val_percent = 0.2
num_rows = len(dfInput.index)
val_size = int(num_rows * val_percent)
train_size = num_rows - val_size
train_ds, val_ds = random_split(dataset, [train_size, val_size])

# %%
batch_size = 11
train_loader = DataLoader(train_ds, batch_size, shuffle = True, num_workers = 0)
val_loader = DataLoader(val_ds, batch_size, num_workers = 0)

# %%
input_size = len(inputs[0])
output_size = 1

# %%
class MultiLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(12, 144),
            nn.ReLU(),
            nn.Linear(144,72),
            nn.ReLU(),
            nn.Linear(72,36),
            nn.ReLU(),
            nn.Linear(36,1),
            
        )
        
    def forward(self, xb):
        out = self.layers(xb)                       
        return out
    
    def training_step(self, batch):
        inputs, targets = batch 
        # Generate predictions
        out = self(inputs)          
        # Calcuate loss
        mse_loss = nn.MSELoss()
        # cross_entropy_loss = nn.CrossEntropyLoss()
        # loss = cross_entropy_loss(out, targets)
        loss = mse_loss(out, targets)  
        return loss
    
    def validation_step(self, batch):
        inputs, targets = batch
        # Generate predictions
        out = self(inputs)
        # Calculate loss
        mse_loss = nn.MSELoss()
        loss = mse_loss(out, targets)    
        return {'val_loss': loss.detach()}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        return {'val_loss': epoch_loss.item()}
    
    def epoch_end(self, epoch, result, num_epochs):
        # Print result every 20th epoch
        if (epoch+1) % 20 == 0 or epoch == num_epochs-1:
            print("Epoch [{}], val_loss: {:.4f}".format(epoch+1, result['val_loss']))

# %%
model = MultiLinearRegressionModel()

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.1508, -0.1456,  0.1148,  ...,  0.0846, -0.2793, -0.2549],
#          [ 0.0211,  0.0762, -0.2578,  ...,  0.0212, -0.1532,  0.2464],
#          [ 0.2351, -0.0186,  0.1612,  ..., -0.2742,  0.0175,  0.2810],
#          ...,
#          [ 0.1602,  0.1947, -0.0283,  ..., -0.0645, -0.0286, -0.0927],
#          [ 0.2861, -0.1225, -0.2205,  ..., -0.2446,  0.1109, -0.2380],
#          [-0.2666,  0.1764, -0.1690,  ..., -0.0604,  0.2199, -0.2397]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0898, -0.2291,  0.1462, -0.2180, -0.2260,  0.2333,  0.1891,  0.1419,
#          -0.1349,  0.2156,  0.1041,  0.2749, -0.0174,  0.1338, -0.2634, -0.2245,
#          -0.2745,  0.2089, -0.1986, -0.1977, -0.0976, -0.1014, -0.1485, -0.1198,
#           0.1416, -0.2115,  0.2703,  0.0978, -0.0322,  0.2251,  0.0091,  0.0632,
#           0.0650,  0.1624, -0.0281, -0.2065,  0.0222,  0.0500, -0.1658, -0.2132,
#           0.0978,  0.2102,  0.1313,  0.2774,  0.1605, -0.0610,  0.2672, -0.0576,
#           0.1077, -0.2684,  0.1437, -0.1219, -0.1654,  0.1350,  0.0999, -0.1905,
#          -0.0281, -0.0796, -0.0433,  0.2817,  0.1191,  0.1885, -0.0807,  0.1550,
#           0.2876,  0.2089, -0.0674, -0.0513,  0.0249, -0.2877, -0.0795,  0.2858,
#           0.2770,  0.2035, -0.2812, -0.2769,  0.2780,  0.2164,  0.0197, -0.0769,
#           0.1921,  0.1294, -0.2092, -0.1671,  0.1112, -0.2795,  0.0465,  0.1495,
#          -0.0279, -0.1207,  0.1434,  0.0995, -0.0227, -0.1225,  0.2293, -0.1894,
#           0.0977,  0.0479, -0.2634,  0.1085, -0.0736,  0.0759, -0.2184, -0.0595,
#          -0.2363,  0.2584,  0.1378, -0.0584, -0.0595, -0.2156, -0.2203, -0.0526,
#          -0.2327,  0.2141, -0.1852,  0.0901, -0.0931, -0.0050, -0.1662, -0.0641,
#           0.0328,  0.0970,  0.1208, -0.1009, -0.2330,  0.2012, -0.1540, -0.2470,
#           0.1316, -0.2871, -0.0470,  0.0469, -0.0401, -0.0666, -0.2161, -0.2689,
#          -0.1057, -0.0373, -0.0042, -0.0909,  0.1416,  0.1174,  0.0936, -0.2605],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0239,  0.0280, -0.0202,  ...,  0.0515, -0.0458, -0.0644],
#          [ 0.0591,  0.0131,  0.0287,  ...,  0.0431, -0.0398,  0.0747],
#          [ 0.0443, -0.0577,  0.0305,  ...,  0.0026,  0.0384,  0.0038],
#          ...,
#          [-0.0798, -0.0662, -0.0187,  ..., -0.0306, -0.0600, -0.0405],
#          [ 0.0402, -0.0738,  0.0411,  ...,  0.0610, -0.0711,  0.0468],
#          [-0.0684,  0.0672,  0.0330,  ..., -0.0194, -0.0123,  0.0698]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0346, -0.0809, -0.0524, -0.0101, -0.0709,  0.0373, -0.0495,  0.0272,
#          -0.0151,  0.0630,  0.0635,  0.0042,  0.0197,  0.0690, -0.0006, -0.0126,
#           0.0663,  0.0781, -0.0693,  0.0680,  0.0268, -0.0138, -0.0455,  0.0049,
#           0.0490, -0.0597, -0.0179,  0.0387,  0.0590, -0.0577,  0.0024, -0.0377,
#           0.0044,  0.0210, -0.0218,  0.0427,  0.0659,  0.0724,  0.0536,  0.0113,
#           0.0696,  0.0429, -0.0612,  0.0357, -0.0531, -0.0508, -0.0210,  0.0039,
#          -0.0121, -0.0224, -0.0169, -0.0764, -0.0790, -0.0222,  0.0003,  0.0223,
#          -0.0733, -0.0078, -0.0591, -0.0060,  0.0533, -0.0015,  0.0110,  0.0749,
#          -0.0727, -0.0523,  0.0488,  0.0497,  0.0183, -0.0713, -0.0299,  0.0777],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0803, -0.1123, -0.0259,  ..., -0.0813, -0.0978, -0.0756],
#          [-0.0701, -0.0589,  0.1009,  ...,  0.0997, -0.0503,  0.0710],
#          [-0.0149, -0.0894, -0.0938,  ...,  0.0006,  0.0066,  0.0035],
#          ...,
#          [ 0.0111,  0.0531, -0.0242,  ..., -0.0783,  0.1076, -0.0213],
#          [-0.0883,  0.0629,  0.0332,  ..., -0.0826, -0.0886,  0.0601],
#          [ 0.0363, -0.0239,  0.0148,  ..., -0.0131, -0.1136,  0.0781]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0348, -0.0894,  0.0916,  0.1035, -0.1045, -0.0432,  0.0949,  0.1159,
#          -0.0644,  0.0453, -0.0827, -0.0857, -0.0687, -0.0503, -0.0803,  0.0159,
#          -0.0939,  0.0734,  0.1130,  0.0298,  0.0150, -0.1116, -0.0313,  0.0581,
#           0.0520, -0.0520, -0.0592,  0.0579, -0.0126,  0.0302,  0.0996, -0.0282,
#           0.0489,  0.0624, -0.0383, -0.0689], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1359,  0.1321,  0.0183, -0.1451, -0.0180, -0.1595, -0.1288,  0.0114,
#           -0.0240, -0.0698,  0.1591,  0.1248, -0.0238, -0.1139, -0.1084,  0.1058,
#           -0.0397,  0.1123,  0.0156, -0.0156,  0.0154,  0.1578, -0.0721, -0.1643,
#            0.1193,  0.0638, -0.0943,  0.0452,  0.1593,  0.1461, -0.0548,  0.0021,
#           -0.0558,  0.0185, -0.1211,  0.1331]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.0801], requires_grad=True)]

# %%
def evaluate(model, val_loader):
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func = torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        for batch in train_loader:
            loss = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        model.epoch_end(epoch, result, epochs)
        history.append(result)
    return history

# %%
result = evaluate(model, val_loader)
print(result)
# Out:
# {'val_loss': 7815.06787109375}

# %%
epochs = 10000
lr = 1e-6
history1 = fit(epochs, lr, model, train_loader, val_loader)
# Out:
# Epoch [20], val_loss: 219.0526
# Epoch [40], val_loss: 194.7022
# Epoch [60], val_loss: 170.2381
# Epoch [80], val_loss: 198.3002
# Epoch [100], val_loss: 154.9489
# Epoch [120], val_loss: 144.5446
# Epoch [140], val_loss: 123.9742
# Epoch [160], val_loss: 109.6525
# Epoch [180], val_loss: 110.1143
# Epoch [200], val_loss: 101.7630
# Epoch [220], val_loss: 98.0861
# Epoch [240], val_loss: 104.2300
# Epoch [260], val_loss: 98.6543
# Epoch [280], val_loss: 95.0267
# Epoch [300], val_loss: 103.0018
# Epoch [320], val_loss: 101.8582
# Epoch [340], val_loss: 92.4573
# Epoch [360], val_loss: 87.6426
# Epoch [380], val_loss: 88.2835
# Epoch [400], val_loss: 90.1196
# Epoch [420], val_loss: 90.9341
# Epoch [440], val_loss: 84.3061
# Epoch [460], val_loss: 91.1636
# Epoch [480], val_loss: 84.2993
# Epoch [500], val_loss: 94.9708
# Epoch [520], val_loss: 92.2600
# Epoch [540], val_loss: 83.5327
# Epoch [560], val_loss: 79.3533
# Epoch [580], val_loss: 84.3526
# Epoch [600], val_loss: 79.1913
# Epoch [620], val_loss: 83.1309
# Epoch [640], val_loss: 114.4921
# Epoch [660], val_loss: 96.1894
# Epoch [680], val_loss: 80.6530
# Epoch [700], val_loss: 70.9334
# Epoch [720], val_loss: 84.1665
# Epoch [740], val_loss: 72.7510
# Epoch [760], val_loss: 74.2174
# Epoch [780], val_loss: 71.5920
# Epoch [800], val_loss: 83.4899
# Epoch [820], val_loss: 74.8725
# Epoch [840], val_loss: 84.5088
# Epoch [860], val_loss: 81.5518
# Epoch [880], val_loss: 73.2760
# Epoch [900], val_loss: 72.4986
# Epoch [920], val_loss: 75.2625
# Epoch [940], val_loss: 79.6469
# Epoch [960], val_loss: 73.7968
# Epoch [980], val_loss: 70.7720
# Epoch [1000], val_loss: 76.4089
# Epoch [1020], val_loss: 70.2637
# Epoch [1040], val_loss: 69.4908
# Epoch [1060], val_loss: 71.4966
# Epoch [1080], val_loss: 70.6712
# Epoch [1100], val_loss: 68.1269
# Epoch [1120], val_loss: 67.7967
# Epoch [1140], val_loss: 67.9564
# Epoch [1160], val_loss: 75.0026
# Epoch [1180], val_loss: 69.5680
# Epoch [1200], val_loss: 82.7709
# Epoch [1220], val_loss: 80.4607
# Epoch [1240], val_loss: 70.3853
# Epoch [1260], val_loss: 68.7075
# Epoch [1280], val_loss: 73.0996
# Epoch [1300], val_loss: 72.6703
# Epoch [1320], val_loss: 67.4184
# Epoch [1340], val_loss: 64.6115
# Epoch [1360], val_loss: 69.1766
# Epoch [1380], val_loss: 74.7694
# Epoch [1400], val_loss: 64.9014
# Epoch [1420], val_loss: 64.7733
# Epoch [1440], val_loss: 66.5342
# Epoch [1460], val_loss: 74.8974
# Epoch [1480], val_loss: 67.9565
# Epoch [1500], val_loss: 65.6775
# Epoch [1520], val_loss: 62.9074
# Epoch [1540], val_loss: 76.1897
# Epoch [1560], val_loss: 70.4579
# Epoch [1580], val_loss: 82.6011
# Epoch [1600], val_loss: 64.7733
# Epoch [1620], val_loss: 68.8012
# Epoch [1640], val_loss: 62.3220
# Epoch [1660], val_loss: 64.4922
# Epoch [1680], val_loss: 83.6462
# Epoch [1700], val_loss: 88.7623
# Epoch [1720], val_loss: 61.2564
# Epoch [1740], val_loss: 58.4095
# Epoch [1760], val_loss: 73.3362
# Epoch [1780], val_loss: 72.2456
# Epoch [1800], val_loss: 63.1737
# Epoch [1820], val_loss: 61.1320
# Epoch [1840], val_loss: 59.4495
# Epoch [1860], val_loss: 64.3419
# Epoch [1880], val_loss: 57.4701
# Epoch [1900], val_loss: 55.4509
# Epoch [1920], val_loss: 58.5473
# Epoch [1940], val_loss: 73.8633
# Epoch [1960], val_loss: 66.1613
# Epoch [1980], val_loss: 63.7668
# Epoch [2000], val_loss: 65.1962
# Epoch [2020], val_loss: 54.5452
# Epoch [2040], val_loss: 68.6590
# Epoch [2060], val_loss: 64.1546
# Epoch [2080], val_loss: 62.9724
# Epoch [2100], val_loss: 60.5902
# Epoch [2120], val_loss: 90.9369
# Epoch [2140], val_loss: 57.7225
# Epoch [2160], val_loss: 69.1879
# Epoch [2180], val_loss: 58.3307
# Epoch [2200], val_loss: 106.9196
# Epoch [2220], val_loss: 62.3883
# Epoch [2240], val_loss: 70.5231
# Epoch [2260], val_loss: 72.9862
# Epoch [2280], val_loss: 59.1661
# Epoch [2300], val_loss: 72.6306
# Epoch [2320], val_loss: 69.6940
# Epoch [2340], val_loss: 75.5666
# Epoch [2360], val_loss: 57.5464
# Epoch [2380], val_loss: 64.3510
# Epoch [2400], val_loss: 63.3334
# Epoch [2420], val_loss: 55.3971
# Epoch [2440], val_loss: 87.8329
# Epoch [2460], val_loss: 65.3874
# Epoch [2480], val_loss: 50.1186
# Epoch [2500], val_loss: 48.9262
# Epoch [2520], val_loss: 55.5741
# Epoch [2540], val_loss: 53.2896
# Epoch [2560], val_loss: 64.8814
# Epoch [2580], val_loss: 49.0259
# Epoch [2600], val_loss: 55.4042
# Epoch [2620], val_loss: 77.1604
# Epoch [2640], val_loss: 57.2500
# Epoch [2660], val_loss: 67.2224
# Epoch [2680], val_loss: 52.0181
# Epoch [2700], val_loss: 60.1878
# Epoch [2720], val_loss: 62.7414
# Epoch [2740], val_loss: 64.7728
# Epoch [2760], val_loss: 55.1891
# Epoch [2780], val_loss: 52.3416
# Epoch [2800], val_loss: 51.5952
# Epoch [2820], val_loss: 56.1912
# Epoch [2840], val_loss: 48.6927
# Epoch [2860], val_loss: 52.1026
# Epoch [2880], val_loss: 48.9045
# Epoch [2900], val_loss: 57.3843
# Epoch [2920], val_loss: 55.6685
# Epoch [2940], val_loss: 49.6167
# Epoch [2960], val_loss: 50.5212
# Epoch [2980], val_loss: 57.0973
# Epoch [3000], val_loss: 54.6239
# Epoch [3020], val_loss: 49.7964
# Epoch [3040], val_loss: 68.3417
# Epoch [3060], val_loss: 72.6541
# Epoch [3080], val_loss: 46.0932
# Epoch [3100], val_loss: 61.7973
# Epoch [3120], val_loss: 64.4856
# Epoch [3140], val_loss: 46.0167
# Epoch [3160], val_loss: 58.4687
# Epoch [3180], val_loss: 70.4286
# Epoch [3200], val_loss: 47.5897
# Epoch [3220], val_loss: 65.3707
# Epoch [3240], val_loss: 63.0923
# Epoch [3260], val_loss: 41.3990
# Epoch [3280], val_loss: 42.0963
# Epoch [3300], val_loss: 45.5760
# Epoch [3320], val_loss: 43.7953
# Epoch [3340], val_loss: 63.4177
# Epoch [3360], val_loss: 42.0578
# Epoch [3380], val_loss: 46.0776
# Epoch [3400], val_loss: 47.2071
# Epoch [3420], val_loss: 44.8419
# Epoch [3440], val_loss: 40.8436
# Epoch [3460], val_loss: 38.2930
# Epoch [3480], val_loss: 86.9887
# Epoch [3500], val_loss: 72.9154
# Epoch [3520], val_loss: 41.0862
# Epoch [3540], val_loss: 62.2532
# Epoch [3560], val_loss: 49.2540
# Epoch [3580], val_loss: 44.0205
# Epoch [3600], val_loss: 41.6619
# Epoch [3620], val_loss: 47.1027
# Epoch [3640], val_loss: 49.9087
# Epoch [3660], val_loss: 39.0804
# Epoch [3680], val_loss: 40.2715
# Epoch [3700], val_loss: 40.3150
# Epoch [3720], val_loss: 39.7500
# Epoch [3740], val_loss: 43.4808
# Epoch [3760], val_loss: 53.6777
# Epoch [3780], val_loss: 50.9608
# Epoch [3800], val_loss: 54.6217
# Epoch [3820], val_loss: 37.8847
# Epoch [3840], val_loss: 44.5527
# Epoch [3860], val_loss: 36.6803
# Epoch [3880], val_loss: 40.7228
# Epoch [3900], val_loss: 40.3232
# Epoch [3920], val_loss: 46.0297
# Epoch [3940], val_loss: 39.0826
# Epoch [3960], val_loss: 37.3885
# Epoch [3980], val_loss: 40.2590
# Epoch [4000], val_loss: 39.9813
# Epoch [4020], val_loss: 58.2186
# Epoch [4040], val_loss: 70.2126
# Epoch [4060], val_loss: 46.1081
# Epoch [4080], val_loss: 64.5596
# Epoch [4100], val_loss: 35.1306
# Epoch [4120], val_loss: 86.0984
# Epoch [4140], val_loss: 46.6384
# Epoch [4160], val_loss: 43.0869
# Epoch [4180], val_loss: 84.8556
# Epoch [4200], val_loss: 87.9842
# Epoch [4220], val_loss: 36.5671
# Epoch [4240], val_loss: 49.9971
# Epoch [4260], val_loss: 34.1418
# Epoch [4280], val_loss: 39.2776
# Epoch [4300], val_loss: 33.1438
# Epoch [4320], val_loss: 40.1511
# Epoch [4340], val_loss: 46.9200
# Epoch [4360], val_loss: 36.0555
# Epoch [4380], val_loss: 38.1936
# Epoch [4400], val_loss: 34.8728
# Epoch [4420], val_loss: 39.1032
# Epoch [4440], val_loss: 43.5879
# Epoch [4460], val_loss: 55.4595
# Epoch [4480], val_loss: 49.7122
# Epoch [4500], val_loss: 38.9914
# Epoch [4520], val_loss: 37.9216
# Epoch [4540], val_loss: 48.0574
# Epoch [4560], val_loss: 33.0061
# Epoch [4580], val_loss: 35.5861
# Epoch [4600], val_loss: 35.8569
# Epoch [4620], val_loss: 67.8388
# Epoch [4640], val_loss: 45.1644
# Epoch [4660], val_loss: 39.7881
# Epoch [4680], val_loss: 38.7971
# Epoch [4700], val_loss: 43.6170
# Epoch [4720], val_loss: 46.0330
# Epoch [4740], val_loss: 35.5666
# Epoch [4760], val_loss: 35.4404
# Epoch [4780], val_loss: 39.2917
# Epoch [4800], val_loss: 34.4655
# Epoch [4820], val_loss: 35.7045
# Epoch [4840], val_loss: 31.3450
# Epoch [4860], val_loss: 98.3621
# Epoch [4880], val_loss: 38.7648
# Epoch [4900], val_loss: 39.4080
# Epoch [4920], val_loss: 37.8478
# Epoch [4940], val_loss: 33.1390
# Epoch [4960], val_loss: 35.7819
# Epoch [4980], val_loss: 58.8162
# Epoch [5000], val_loss: 33.7355
# Epoch [5020], val_loss: 38.9032
# Epoch [5040], val_loss: 40.0004
# Epoch [5060], val_loss: 37.6143
# Epoch [5080], val_loss: 34.5141
# Epoch [5100], val_loss: 37.1585
# Epoch [5120], val_loss: 34.5579
# Epoch [5140], val_loss: 56.5306
# Epoch [5160], val_loss: 40.8515
# Epoch [5180], val_loss: 35.0873
# Epoch [5200], val_loss: 34.2711
# Epoch [5220], val_loss: 38.1994
# Epoch [5240], val_loss: 34.9339
# Epoch [5260], val_loss: 32.0758
# Epoch [5280], val_loss: 34.2142
# Epoch [5300], val_loss: 65.2012
# Epoch [5320], val_loss: 39.0828
# Epoch [5340], val_loss: 29.5542
# Epoch [5360], val_loss: 30.9995
# Epoch [5380], val_loss: 31.4873
# Epoch [5400], val_loss: 50.3900
# Epoch [5420], val_loss: 30.7552
# Epoch [5440], val_loss: 38.9706
# Epoch [5460], val_loss: 38.1218
# Epoch [5480], val_loss: 33.3274
# Epoch [5500], val_loss: 33.2659
# Epoch [5520], val_loss: 29.3776
# Epoch [5540], val_loss: 33.2151
# Epoch [5560], val_loss: 28.1144
# Epoch [5580], val_loss: 38.3766
# Epoch [5600], val_loss: 40.5131
# Epoch [5620], val_loss: 33.8261
# Epoch [5640], val_loss: 69.9027
# Epoch [5660], val_loss: 42.6835
# Epoch [5680], val_loss: 37.5133
# Epoch [5700], val_loss: 34.5131
# Epoch [5720], val_loss: 29.3399
# Epoch [5740], val_loss: 50.3203
# Epoch [5760], val_loss: 62.1918
# Epoch [5780], val_loss: 30.9727
# Epoch [5800], val_loss: 94.8735
# Epoch [5820], val_loss: 30.3064
# Epoch [5840], val_loss: 36.7075
# Epoch [5860], val_loss: 65.6342
# Epoch [5880], val_loss: 31.6787
# Epoch [5900], val_loss: 36.2890
# Epoch [5920], val_loss: 37.1214
# Epoch [5940], val_loss: 28.6833
# Epoch [5960], val_loss: 29.2724
# Epoch [5980], val_loss: 31.4869
# Epoch [6000], val_loss: 35.6816
# Epoch [6020], val_loss: 33.3463
# Epoch [6040], val_loss: 43.7503
# Epoch [6060], val_loss: 33.4249
# Epoch [6080], val_loss: 50.5077
# Epoch [6100], val_loss: 29.6527
# Epoch [6120], val_loss: 33.2570
# Epoch [6140], val_loss: 28.8690
# Epoch [6160], val_loss: 61.1000
# Epoch [6180], val_loss: 29.9182
# Epoch [6200], val_loss: 83.9520
# Epoch [6220], val_loss: 119.2848
# Epoch [6240], val_loss: 31.6638
# Epoch [6260], val_loss: 33.3485
# Epoch [6280], val_loss: 36.5748
# Epoch [6300], val_loss: 24.5100
# Epoch [6320], val_loss: 26.3000
# Epoch [6340], val_loss: 37.9691
# Epoch [6360], val_loss: 25.9546
# Epoch [6380], val_loss: 30.8198
# Epoch [6400], val_loss: 26.9800
# Epoch [6420], val_loss: 31.4161
# Epoch [6440], val_loss: 36.0192
# Epoch [6460], val_loss: 25.7606
# Epoch [6480], val_loss: 71.5184
# Epoch [6500], val_loss: 30.5311
# Epoch [6520], val_loss: 46.5613
# Epoch [6540], val_loss: 33.0758
# Epoch [6560], val_loss: 37.8432
# Epoch [6580], val_loss: 28.6673
# Epoch [6600], val_loss: 31.3464
# Epoch [6620], val_loss: 37.7665
# Epoch [6640], val_loss: 32.3309
# Epoch [6660], val_loss: 39.7213
# Epoch [6680], val_loss: 25.9081
# Epoch [6700], val_loss: 42.2983
# Epoch [6720], val_loss: 44.0393
# Epoch [6740], val_loss: 37.3309
# Epoch [6760], val_loss: 28.5777
# Epoch [6780], val_loss: 27.2984
# Epoch [6800], val_loss: 25.1777
# Epoch [6820], val_loss: 38.2145
# Epoch [6840], val_loss: 38.6412
# Epoch [6860], val_loss: 24.3423
# Epoch [6880], val_loss: 27.4550
# Epoch [6900], val_loss: 24.5322
# Epoch [6920], val_loss: 37.0419
# Epoch [6940], val_loss: 24.5141
# Epoch [6960], val_loss: 24.5267
# Epoch [6980], val_loss: 28.7221
# Epoch [7000], val_loss: 29.8694
# Epoch [7020], val_loss: 27.4799
# Epoch [7040], val_loss: 68.0235
# Epoch [7060], val_loss: 43.9449
# Epoch [7080], val_loss: 40.6941
# Epoch [7100], val_loss: 26.4301
# Epoch [7120], val_loss: 26.0389
# Epoch [7140], val_loss: 24.0056
# Epoch [7160], val_loss: 53.7561
# Epoch [7180], val_loss: 27.8207
# Epoch [7200], val_loss: 32.9035
# Epoch [7220], val_loss: 23.9201
# Epoch [7240], val_loss: 29.0315
# Epoch [7260], val_loss: 38.0970
# Epoch [7280], val_loss: 34.7174
# Epoch [7300], val_loss: 29.1740
# Epoch [7320], val_loss: 24.3825
# Epoch [7340], val_loss: 25.3951
# Epoch [7360], val_loss: 36.4081
# Epoch [7380], val_loss: 39.7826
# Epoch [7400], val_loss: 24.1105
# Epoch [7420], val_loss: 30.1193
# Epoch [7440], val_loss: 30.1569
# Epoch [7460], val_loss: 25.9086
# Epoch [7480], val_loss: 30.6955
# Epoch [7500], val_loss: 23.9235
# Epoch [7520], val_loss: 25.7082
# Epoch [7540], val_loss: 25.5964
# Epoch [7560], val_loss: 32.8065
# Epoch [7580], val_loss: 24.0398
# Epoch [7600], val_loss: 23.0720
# Epoch [7620], val_loss: 35.4147
# Epoch [7640], val_loss: 47.1387
# Epoch [7660], val_loss: 22.9598
# Epoch [7680], val_loss: 55.0242
# Epoch [7700], val_loss: 24.8434
# Epoch [7720], val_loss: 23.3152
# Epoch [7740], val_loss: 32.1250
# Epoch [7760], val_loss: 57.0304
# Epoch [7780], val_loss: 23.0612
# Epoch [7800], val_loss: 28.1015
# Epoch [7820], val_loss: 21.9764
# Epoch [7840], val_loss: 25.2611
# Epoch [7860], val_loss: 24.7279
# Epoch [7880], val_loss: 20.9689
# Epoch [7900], val_loss: 22.9829
# Epoch [7920], val_loss: 22.1841
# Epoch [7940], val_loss: 48.8106
# Epoch [7960], val_loss: 26.9727
# Epoch [7980], val_loss: 26.2355
# Epoch [8000], val_loss: 26.2984
# Epoch [8020], val_loss: 24.5733
# Epoch [8040], val_loss: 24.7775
# Epoch [8060], val_loss: 29.6607
# Epoch [8080], val_loss: 29.4790
# Epoch [8100], val_loss: 29.4614
# Epoch [8120], val_loss: 31.3794
# Epoch [8140], val_loss: 50.8841
# Epoch [8160], val_loss: 22.8015
# Epoch [8180], val_loss: 24.0443
# Epoch [8200], val_loss: 21.2129
# Epoch [8220], val_loss: 22.1267
# Epoch [8240], val_loss: 21.8549
# Epoch [8260], val_loss: 29.7271
# Epoch [8280], val_loss: 34.8857
# Epoch [8300], val_loss: 20.3997
# Epoch [8320], val_loss: 42.4381
# Epoch [8340], val_loss: 29.0550
# Epoch [8360], val_loss: 21.7907
# Epoch [8380], val_loss: 22.8009
# Epoch [8400], val_loss: 23.2046
# Epoch [8420], val_loss: 22.4594
# Epoch [8440], val_loss: 35.6657
# Epoch [8460], val_loss: 38.3660
# Epoch [8480], val_loss: 24.5558
# Epoch [8500], val_loss: 19.8755
# Epoch [8520], val_loss: 24.9595
# Epoch [8540], val_loss: 25.4474
# Epoch [8560], val_loss: 53.4778
# Epoch [8580], val_loss: 25.5074
# Epoch [8600], val_loss: 21.0340
# Epoch [8620], val_loss: 22.0334
# Epoch [8640], val_loss: 32.1162
# Epoch [8660], val_loss: 25.6177
# Epoch [8680], val_loss: 34.3544
# Epoch [8700], val_loss: 22.3672
# Epoch [8720], val_loss: 23.7792
# Epoch [8740], val_loss: 23.9377
# Epoch [8760], val_loss: 23.0013
# Epoch [8780], val_loss: 22.9358
# Epoch [8800], val_loss: 19.2289
# Epoch [8820], val_loss: 22.9103
# Epoch [8840], val_loss: 25.1718
# Epoch [8860], val_loss: 22.8107
# Epoch [8880], val_loss: 23.6235
# Epoch [8900], val_loss: 21.4824
# Epoch [8920], val_loss: 22.8789
# Epoch [8940], val_loss: 27.5512
# Epoch [8960], val_loss: 23.0820
# Epoch [8980], val_loss: 25.6246
# Epoch [9000], val_loss: 35.6282
# Epoch [9020], val_loss: 26.5634
# Epoch [9040], val_loss: 23.1024
# Epoch [9060], val_loss: 20.9826
# Epoch [9080], val_loss: 21.3375
# Epoch [9100], val_loss: 25.9612
# Epoch [9120], val_loss: 20.1470
# Epoch [9140], val_loss: 24.3557
# Epoch [9160], val_loss: 21.3116
# Epoch [9180], val_loss: 21.9459
# Epoch [9200], val_loss: 21.1689
# Epoch [9220], val_loss: 22.5998
# Epoch [9240], val_loss: 23.1480
# Epoch [9260], val_loss: 20.7686
# Epoch [9280], val_loss: 19.3236
# Epoch [9300], val_loss: 23.2123
# Epoch [9320], val_loss: 24.5111
# Epoch [9340], val_loss: 19.4220
# Epoch [9360], val_loss: 33.0551
# Epoch [9380], val_loss: 21.6512
# Epoch [9400], val_loss: 32.7085
# Epoch [9420], val_loss: 32.0843
# Epoch [9440], val_loss: 29.5923
# Epoch [9460], val_loss: 24.7078
# Epoch [9480], val_loss: 20.9080
# Epoch [9500], val_loss: 18.3603
# Epoch [9520], val_loss: 21.3080
# Epoch [9540], val_loss: 22.1728
# Epoch [9560], val_loss: 32.8146
# Epoch [9580], val_loss: 28.1155
# Epoch [9600], val_loss: 19.1837
# Epoch [9620], val_loss: 23.6851
# Epoch [9640], val_loss: 24.2396
# Epoch [9660], val_loss: 23.6057
# Epoch [9680], val_loss: 24.8603
# Epoch [9700], val_loss: 43.4297
# Epoch [9720], val_loss: 26.4326
# Epoch [9740], val_loss: 22.5820
# Epoch [9760], val_loss: 18.5395
# Epoch [9780], val_loss: 27.7276
# Epoch [9800], val_loss: 19.1256
# Epoch [9820], val_loss: 26.4666
# Epoch [9840], val_loss: 22.7271
# Epoch [9860], val_loss: 19.2756
# Epoch [9880], val_loss: 20.5103
# Epoch [9900], val_loss: 24.4850
# Epoch [9920], val_loss: 20.5958
# Epoch [9940], val_loss: 18.5795
# Epoch [9960], val_loss: 25.1885
# Epoch [9980], val_loss: 21.3642
# Epoch [10000], val_loss: 22.7672

# %%
def predict_single(input, target, model):
    inputs = input.unsqueeze(0)
    predictions = model(inputs)                
    prediction = predictions[0].detach()
    return target, prediction

# %%
input, target = val_ds[12]
predict_single(input, target, model)
# Out:
# (tensor([79.1890]), tensor([80.1760]))

# %%
input, target = val_ds[50]
predict_single(input, target, model)
# Out:
# (tensor([83.6090]), tensor([88.6678]))

# %%
def get_accuracy(predict,actual):
        predict = predict.detach().numpy()
        actual = actual.numpy()

        count = 0

        for i in range(len(actual)):
            if predict[i] >= actual[i]*.99 and predict[i] <= actual[i]*1.01:
                count+=1
        return count/len(predict)*100

# %%
targets = []
predictions = []
for i in range(len(val_ds)):
    input, target = val_ds[i]
    target, prediction = predict_single(input, target, model)
    # np.append(targets,target)
    targets.append(target)
    predictions.append(prediction)
    # np.append(predictions,prediction)

# print(len(predictions))
# print(targets[0])
accuracy = []
for j in range(len(predictions)-1):
    accuracy.append(get_accuracy(predictions[j],targets[j]))

# %%
print(np.sum(accuracy)/len(accuracy))
# Out:
# 22.570076447033127

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.scatter(range(len(predictions)),targets)
ax.scatter(range(len(predictions)), predictions)
# Out:
# C:\Users\peter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\ma\core.py:2826: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   _data = np.array(data, dtype=dtype, copy=copy,
# C:\Users\peter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\ma\core.py:2826: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   _data = np.array(data, dtype=dtype, copy=copy,
